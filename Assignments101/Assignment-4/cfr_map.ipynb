# %%
#Victoria Savage
#100556060
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from JSAnimation.IPython_display import display_animation
import urllib
from mpl_toolkits.basemap import Basemap
import csv

# %%
Category = []
Lat = []
Long = []
Cases = []

#first map
#this makes the figure size i put 13 for fun 
fig = plt.figure(figsize=(13,13))
ax = plt.subplot(1,1,1)
#i need the earthquake program so we can plot
Earth = Basemap(projection='mill')
Earth.drawcoastlines(color='0.50', linewidth=0.25)
Earth.fillcontinents(color='0.95')
#i nee to open this file to get the info for the map
with open('Source_data_for_CFR_vaccine_map_abridged.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        Category.append(row['Category'])
        Lat.append((float)(row['Lat']))
        Long.append((float)(row['Long']))
        Cases.append((float)(row['Cases']))   
        #im organizing my map layout so it can be plotted
list(map(float, Lat))
list(map(float, Long))
list(map(float, Cases))
#now i got to go look for the right data for this map i the info file
x = 0
for i in range (x, len(Category)):
    if (Category[x] == 'Measles'):
        x, y = earth(Long[x], Lat[x])
        
        if (Cases[x] >= 0 and Cases[x] < 5000):
            earth.plot(x, y, 'ro',markersize=5,alpha=.5)
            
        elif (Cases[k] >= 5000 and Cases[x] < 140000):
            earth.plot(x, y, 'ro',markersize=((Cases[x])/1000),alpha=.5)
    x += 1
    
plt.title("Measles Outbreaks (100556060)")
plt.show()


#second map.............................................................
#this makes the figure size i put 13 for fun 
plt.figure(figsize=(13, 13))
#i need the earthquake program so we can plot
Earth = Basemap(projection='mill')
Earth.drawcoastlines(color='0.50', linewidth=0.25)
Earth.fillcontinents(color='0.95')
#i nee to open this file to get the info for the map
with open('Source_data_for_CFR_vaccine_map_abridged.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        Category.append(row['Category'])
        Lat.append((float)(row['Lat']))
        Long.append((float)(row['Long']))
        Cases.append((float)(row['Cases']))
        #im organizing my map layout so it can be plotted
list(map(float, Lat))
list(map(float, Long))
list(map(float, Cases))
#now i got to go look for the right data for this map i the info file
r = 0
for i in range (r, len(Category)):
    if (Category[r] == 'Rubella'):
        x, y = earth(Long[r], Lat[l])
        
        if(Cases[r] >= 0 and Cases[r] < 5000):
            earth.plot(x, y, 'mo',markersize=5,alpha=.5)
            
        elif(Cases[r] >= 5000 and Cases[r] < 140000):
            earth.plot(x, y, 'mo',markersize=((Cases[r])/1000),alpha=.5)
    r += 1      
    
plt.title("Rubella outbreaks (100556060)")
plt.show()


#third map..............................................................
#this makes the figure size i put 13 for fun 
plt.figure(figsize=(13, 13))
#i need the earthquake program so we can plot
earth = Basemap(projection='mill')
earth.drawcoastlines(color='0.50', linewidth=0.25)
earth.fillcontinents(color='0.95')
#i nee to open this file to get the info for the map
with open('Source_data_for_CFR_vaccine_map_abridged.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        Category.append(row['Category'])
        Lat.append((float)(row['Lat']))
        Long.append((float)(row['Long']))
        Cases.append((float)(row['Cases']))
        #im organizing my map layout so it can be plotted
list(map(float, Lat))
list(map(float, Long))
list(map(float, Cases))
#now i got to go look for the right data for this map i the info file
m = 0
for i in range (m, len(Category)):
    if (Category[m] == 'Mumps'):
        x, y = earth(Long[m], Lat[m])
        
        if (Cases[m] >= 0 and Cases[m] < 5000):
            earth.plot(x, y, 'go',markersize=5,alpha=.5)
            
        elif(Cases[m] >= 5000 and Cases[m] < 140000):
            earth.plot(x, y, 'go',markersize=((Cases[m])/1000),alpha=.5)
    m += 1      
    
plt.title("Mumps Outbreaks (100556060)")
plt.show()


#fourth map...........................................................
#this makes the figure size i put 13 for fun 
plt.figure(figsize=(13, 13))
#i need the earthquake program so we can plot
earth = Basemap(projection='mill')
earth.drawcoastlines(color='0.50', linewidth=0.25)
earth.fillcontinents(color='0.95')
#i nee to open this file to get the info for the map
with open('Source_data_for_CFR_vaccine_map_abridged.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        Category.append(row['Category'])
        Lat.append((float)(row['Lat']))
        Long.append((float)(row['Long']))
        Cases.append((float)(row['Cases']))
        #im organizing my map layout so it can be plotted
list(map(float, Lat))
list(map(float, Long))
list(map(float, Cases))
#now i got to go look for the right data for this map i the info file
p = 0
for i in range (p, len(Category)):
    if (Category[p] == 'Polio'):
        x, y = earth(Long[n], Lat[p])
        if (Cases[p] >= 0 and Cases[p] < 5000):
            earth.plot(x, y, 'bo',markersize=5,alpha=.5)
            
        elif(Cases[p] >= 5000 and Cases[p] < 140000):
            earth.plot(x, y, 'bo',markersize=((Cases[p])/1000),alpha=.5)
    p += 1      
    
plt.title("Polio Outbreaks (100556060)")
plt.show()
